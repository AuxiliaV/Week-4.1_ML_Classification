# %%
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")
dataset=dataset.drop("User ID",axis=1)
dataset=pd.get_dummies(dataset,drop_first=True).astype(int)
dataset.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
indep=dataset[['Age', 'EstimatedSalary', 'Gender_Male']]
indep.shape
# Out:
# (400, 3)

# %%
dep=dataset[['Purchased']]
dep.value_counts()
# Out:
# Purchased
# 0            257
# 1            143
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=1/3,random_state=0)

# %%
#from sklearn.preprocessing import StandardScaler
#sc=StandardScaler()
#x_train=sc.fit_transform(x_train)
#x_test=sc.transform(x_test)
#Standard Scaler for x Adds negative values to the input, which is not supported by CategoricalNB algorithm

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import CategoricalNB
para={'alpha':[0.01,0.1,1.0,10.0],'fit_prior':[True,False]}
grid=GridSearchCV(CategoricalNB(),para,refit=True,verbose=3,n_jobs=1,scoring='f1_weighted')
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5] END ........alpha=0.01, fit_prior=True;, score=0.719 total time=   0.0s
# [CV 2/5] END ........alpha=0.01, fit_prior=True;, score=0.743 total time=   0.0s
# [CV 3/5] END ........alpha=0.01, fit_prior=True;, score=0.711 total time=   0.0s
# [CV 4/5] END ........alpha=0.01, fit_prior=True;, score=0.805 total time=   0.0s
# [CV 5/5] END ..........alpha=0.01, fit_prior=True;, score=nan total time=   0.0s
# [CV 1/5] END .......alpha=0.01, fit_prior=False;, score=0.719 total time=   0.0s
# [CV 2/5] END .......alpha=0.01, fit_prior=False;, score=0.749 total time=   0.0s
# [CV 3/5] END .......alpha=0.01, fit_prior=False;, score=0.732 total time=   0.0s
# [CV 4/5] END .......alpha=0.01, fit_prior=False;, score=0.813 total time=   0.0s
# [CV 5/5] END .........alpha=0.01, fit_prior=False;, score=nan total time=   0.0s
# [CV 1/5] END .........alpha=0.1, fit_prior=True;, score=0.736 total time=   0.0s
# ...

# %%
y_pred=grid.predict(x_test)

# %%
result=grid.cv_results_
table=pd.DataFrame.from_dict(result)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 0       0.013468      0.004999         0.006630        0.006135         0.01
# 1       0.013464      0.006801         0.003470        0.002904         0.01
# 2       0.019565      0.012255         0.004305        0.003617         0.10
# 3       0.013049      0.006542         0.003184        0.006367         0.10
# 4       0.011274      0.006685         0.007296        0.007291         1.00
# 5       0.014704      0.002799         0.002967        0.003635         1.00
# 6       0.012760      0.006381         0.003199        0.006398        10.00
# 7       0.015175      0.000820         0.004130        0.004334        10.00
#
#    param_fit_prior                               params  split0_test_score  \
# 0             True   {'alpha': 0.01, 'fit_prior': True}           0.719468
# 1            False  {'alpha': 0.01, 'fit_prior': False}           0.719468
# ...

# %%
table.to_excel("Grid_NB_Categorical_results.xlsx",index=False)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[77  8]
#  [15 34]]

# %%
from sklearn.metrics import classification_report
report=classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87        85
#            1       0.81      0.69      0.75        49
#
#     accuracy                           0.83       134
#    macro avg       0.82      0.80      0.81       134
# weighted avg       0.83      0.83      0.83       134

# %%
from sklearn.metrics import f1_score
F1=f1_score(y_test,y_pred,average='weighted')
print(F1)
# Out:
# 0.8251506483229225

# %%
from sklearn.metrics import roc_auc_score
score=roc_auc_score(y_test,grid.predict_proba(x_test)[:,1])
score
# Out:
# 0.8351740696278511

# %%
print("the best parameters for Categorical_Naives_Bayes is: {}".format(grid.best_params_),F1)
# Out:
# the best parameters for Categorical_Naives_Bayes is: {'alpha': 0.01, 'fit_prior': True} 0.8251506483229225

# %%
age=float(input("Age:"))
salary=float(input("Salary:"))
gender=float(input("Gender Male:"))
result=grid.predict([[age,salary,gender]])
result
# Out:
# Age: 30
# Salary: 100000
# Gender Male: 0
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but CategoricalNB was fitted with feature names
#   warnings.warn(
# array([1])
