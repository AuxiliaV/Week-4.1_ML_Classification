# %%
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")
dataset=dataset.drop("User ID",axis=1)
dataset=pd.get_dummies(dataset,drop_first=True).astype(int)
dataset.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
indep=dataset[['Age', 'EstimatedSalary', 'Gender_Male']]
indep.shape
# Out:
# (400, 3)

# %%
dep=dataset[['Purchased']]
dep.value_counts()
# Out:
# Purchased
# 0            257
# 1            143
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import BernoulliNB
para={'alpha':[0.01,0.1,1.0,10.0],'fit_prior':[True,False]}
grid=GridSearchCV(BernoulliNB(),para,refit=True,verbose=3,n_jobs=1,scoring='f1_weighted')
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5] END ........alpha=0.01, fit_prior=True;, score=0.732 total time=   0.0s
# [CV 2/5] END ........alpha=0.01, fit_prior=True;, score=0.720 total time=   0.0s
# [CV 3/5] END ........alpha=0.01, fit_prior=True;, score=0.548 total time=   0.0s
# [CV 4/5] END ........alpha=0.01, fit_prior=True;, score=0.749 total time=   0.0s
# [CV 5/5] END ........alpha=0.01, fit_prior=True;, score=0.722 total time=   0.0s
# [CV 1/5] END .......alpha=0.01, fit_prior=False;, score=0.726 total time=   0.0s
# [CV 2/5] END .......alpha=0.01, fit_prior=False;, score=0.687 total time=   0.0s
# [CV 3/5] END .......alpha=0.01, fit_prior=False;, score=0.667 total time=   0.0s
# [CV 4/5] END .......alpha=0.01, fit_prior=False;, score=0.759 total time=   0.0s
# [CV 5/5] END .......alpha=0.01, fit_prior=False;, score=0.778 total time=   0.0s
# [CV 1/5] END .........alpha=0.1, fit_prior=True;, score=0.732 total time=   0.0s
# ...

# %%
y_pred=grid.predict(x_test)

# %%
result=grid.cv_results_
table=pd.DataFrame.from_dict(result)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 0       0.006426      0.002214         0.009361        0.006033         0.01
# 1       0.001605      0.000802         0.008110        0.004268         0.01
# 2       0.004897      0.002120         0.001533        0.002015         0.10
# 3       0.000000      0.000000         0.008524        0.007231         0.10
# 4       0.001762      0.002221         0.008119        0.005222         1.00
# 5       0.002880      0.003553         0.008067        0.001561         1.00
# 6       0.006619      0.004932         0.000247        0.000494        10.00
# 7       0.000401      0.000802         0.007925        0.006909        10.00
#
#    param_fit_prior                               params  split0_test_score  \
# 0             True   {'alpha': 0.01, 'fit_prior': True}           0.732497
# 1            False  {'alpha': 0.01, 'fit_prior': False}           0.726166
# ...

# %%
table.to_excel("Grid_NB_Bernoulli_results.xlsx",index=False)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[64 21]
#  [ 9 40]]

# %%
from sklearn.metrics import classification_report
report=classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.75      0.81        85
#            1       0.66      0.82      0.73        49
#
#     accuracy                           0.78       134
#    macro avg       0.77      0.78      0.77       134
# weighted avg       0.80      0.78      0.78       134

# %%
from sklearn.metrics import f1_score
F1=f1_score(y_test,y_pred,average='weighted')
print(F1)
# Out:
# 0.7798292770898099

# %%
from sklearn.metrics import roc_auc_score
score=roc_auc_score(y_test,grid.predict_proba(x_test)[:,1])
score
# Out:
# 0.8474189675870348

# %%
print("the best parameters for Bernoulli_Naives_Bayes is: {}".format(grid.best_params_),F1)
# Out:
# the best parameters for Bernoulli_Naives_Bayes is: {'alpha': 0.01, 'fit_prior': False} 0.7798292770898099

# %%
age=float(input("Age:"))
salary=float(input("Salary:"))
gender=float(input("Gender Male:"))
result=grid.predict([[age,salary,gender]])
result
# Out:
# Age: 30
# Salary: 100000
# Gender Male: 0
# array([1])
