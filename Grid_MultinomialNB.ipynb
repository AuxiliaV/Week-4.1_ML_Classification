# %%
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")
dataset=dataset.drop("User ID",axis=1)
dataset=pd.get_dummies(dataset,drop_first=True).astype(int)
dataset.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
indep=dataset[['Age', 'EstimatedSalary', 'Gender_Male']]
indep.shape
# Out:
# (400, 3)

# %%
dep=dataset[['Purchased']]
dep.value_counts()
# Out:
# Purchased
# 0            257
# 1            143
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=1/3,random_state=0)

# %%
#from sklearn.preprocessing import StandardScaler
#sc=StandardScaler()
#x_train=sc.fit_transform(x_train)
#x_test=sc.transform(x_test)
#Standard Scaler for x Adds negative values to the input, which is not supported by MultinomialNB algorithm

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import MultinomialNB
para={'alpha':[0.01,0.1,1.0,10.0],'fit_prior':[True,False]}
grid=GridSearchCV(MultinomialNB(),para,refit=True,verbose=3,n_jobs=1,scoring='f1_weighted')
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5] END ........alpha=0.01, fit_prior=True;, score=0.510 total time=   0.0s
# [CV 2/5] END ........alpha=0.01, fit_prior=True;, score=0.567 total time=   0.0s
# [CV 3/5] END ........alpha=0.01, fit_prior=True;, score=0.590 total time=   0.0s
# [CV 4/5] END ........alpha=0.01, fit_prior=True;, score=0.636 total time=   0.0s
# [CV 5/5] END ........alpha=0.01, fit_prior=True;, score=0.557 total time=   0.0s
# [CV 1/5] END .......alpha=0.01, fit_prior=False;, score=0.510 total time=   0.0s
# [CV 2/5] END .......alpha=0.01, fit_prior=False;, score=0.614 total time=   0.0s
# [CV 3/5] END .......alpha=0.01, fit_prior=False;, score=0.563 total time=   0.0s
# [CV 4/5] END .......alpha=0.01, fit_prior=False;, score=0.482 total time=   0.0s
# [CV 5/5] END .......alpha=0.01, fit_prior=False;, score=0.556 total time=   0.0s
# [CV 1/5] END .........alpha=0.1, fit_prior=True;, score=0.510 total time=   0.0s
# ...

# %%
y_pred=grid.predict(x_test)

# %%
result=grid.cv_results_
table=pd.DataFrame.from_dict(result)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 0       0.005105      0.003862         0.015261        0.004547         0.01
# 1       0.003402      0.004167         0.008158        0.000368         0.01
# 2       0.000000      0.000000         0.006527        0.005633         0.10
# 3       0.006339      0.007765         0.003160        0.006321         0.10
# 4       0.004784      0.006312         0.006511        0.004483         1.00
# 5       0.004715      0.003858         0.002826        0.005278         1.00
# 6       0.001689      0.003379         0.007215        0.003518        10.00
# 7       0.000000      0.000000         0.007706        0.000763        10.00
#
#    param_fit_prior                               params  split0_test_score  \
# 0             True   {'alpha': 0.01, 'fit_prior': True}           0.509779
# 1            False  {'alpha': 0.01, 'fit_prior': False}           0.509839
# ...

# %%
table.to_excel("Grid_NB_Multinomial_results.xlsx",index=False)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[85  0]
#  [49  0]]

# %%
from sklearn.metrics import classification_report
report=classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      1.00      0.78        85
#            1       0.00      0.00      0.00        49
#
#     accuracy                           0.63       134
#    macro avg       0.32      0.50      0.39       134
# weighted avg       0.40      0.63      0.49       134
# C:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from sklearn.metrics import f1_score
F1=f1_score(y_test,y_pred,average='weighted')
print(F1)
# Out:
# 0.49240100865535336

# %%
from sklearn.metrics import roc_auc_score
score=roc_auc_score(y_test,grid.predict_proba(x_test)[:,1])
score
# Out:
# 0.5834333733493396

# %%
print("the best parameters for Multinomial_Naives_Bayes is: {}".format(grid.best_params_),F1)
# Out:
# the best parameters for Multinomial_Naives_Bayes is: {'alpha': 0.01, 'fit_prior': True} 0.49240100865535336

# %%
age=float(input("Age:"))
salary=float(input("Salary:"))
gender=float(input("Gender Male:"))
result=grid.predict([[age,salary,gender]])
result
# Out:
# Age: 30
# Salary: 100000
# Gender Male: 0
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MultinomialNB was fitted with feature names
#   warnings.warn(
# array([0])
